# %%
from gcodeparser import GcodeParser

# open gcode file and store contents as variable
with open('cube.gcode', 'r') as f:
  gcode = f.read()

X=GcodeParser(gcode).lines# get parsed gcode lines

# %%
for i in range (len (X)):
    X[i]=X[i].gcode_str
    X[i]=X[i].split( )
    G,t=X[i],0
    for j in range (len (X[i])):
        if (t==1):
            G.remove(G[l])
        elif(G[j]==";"):
            G.remove(G[j])
            t=1
            l=j
    print (X[i])
# Out:
# ['G21']
# ['M82']
# ['G90']
# ['M117', 'HTrue', 'OTrue']
# ['G28', 'X0', 'Y0']
# ['M117', 'HTrue', 'OTrue']
# ['G28', 'Z0']
# ['M117', 'STrue', 'TTrue', 'ATrue', 'RTrue', 'HTrue', 'ETrue', 'ITrue', 'NTrue']
# ['M190', 'S55']
# ['M117', 'STrue', 'TTrue', 'ATrue', 'RTrue', 'HTrue', 'ETrue', 'ITrue', 'NTrue']
# ['M104', 'S210']
# ['M117', 'HTrue', 'ETrue', 'ATrue', 'TTrue', 'ITrue', 'NTrue']
# ['M109', 'S210']
# ['M117', 'PTrue', 'UTrue', 'RTrue']
# ['G92', 'E0']
# ['G1', 'Z1.0', 'F3000']
# ['G1', 'X20', 'Y10', 'Z0.3', 'F5000.0']
# ['G1', 'X150', 'Y10', 'Z0.3', 'F1500.0', 'E15']
# ['G1', 'X150', 'Y10', 'Z0.3', 'F5000.0']
# ['G1', 'X20', 'Y10.3', 'Z0.3', 'F1500.0', 'E30']
# ['G92', 'E0']
# ['M117', 'PTrue', 'RTrue', 'ITrue', 'NTrue', 'TTrue']
# ['M106', 'S0']
# ['G1', 'Z0.28']
# ['G1', 'F1800', 'E-7.0']
# ['G0', 'F7200', 'X109.2', 'Y106.6', 'Z0.28']
# ['G1', 'F1800', 'E0.0']
# ['G1', 'F1200', 'X108.776', 'Y106.639', 'E0.019826']
# ['G1', 'X108.623', 'Y106.666', 'E0.027061']
# ['G1', 'X108.314', 'Y106.757', 'E0.04206']
# ['G1', 'X107.869', 'Y106.971', 'E0.065053']
# ['G1', 'X107.808', 'Y107.008', 'E0.068375']
# ['G1', 'X107.51', 'Y107.228', 'E0.085622']
# ['G1', 'X107.459', 'Y107.274', 'E0.088821']
# ['G1', 'X107.16', 'Y107.594', 'E0.109213']
# ['G1', 'X106.951', 'Y107.901', 'E0.126507']
# ['G1', 'X106.79', 'Y108.23', 'E0.143563']
# ['G1', 'X106.664', 'Y108.645', 'E0.163757']
# ['G1', 'X106.606', 'Y109.075', 'E0.183961']
# ['G1', 'X106.6', 'Y110.799', 'E0.264239']
# ['G1', 'X106.639', 'Y111.224', 'E0.284112']
# ['G1', 'X106.666', 'Y111.377', 'E0.291346']
# ['G1', 'X106.757', 'Y111.686', 'E0.306345']
# ['G1', 'X106.971', 'Y112.131', 'E0.329338']
# ['G1', 'X107.008', 'Y112.192', 'E0.33266']
# ['G1', 'X107.228', 'Y112.49', 'E0.349908']
# ['G1', 'X107.274', 'Y112.541', 'E0.353106']
# ['G1', 'X107.594', 'Y112.84', 'E0.373499']
# ['G1', 'X107.901', 'Y113.049', 'E0.390792']
# ['G1', 'X108.23', 'Y113.21', 'E0.407848']
# ['G1', 'X108.645', 'Y113.336', 'E0.428043']
# ['G1', 'X109.075', 'Y113.394', 'E0.448247']
# ['G1', 'X110.799', 'Y113.4', 'E0.528524']
# ['G1', 'X111.224', 'Y113.361', 'E0.548397']
# ['G1', 'X111.377', 'Y113.334', 'E0.555631']
# ['G1', 'X111.686', 'Y113.243', 'E0.570631']
# ['G1', 'X112.131', 'Y113.029', 'E0.593623']
# ['G1', 'X112.192', 'Y112.992', 'E0.596945']
# ['G1', 'X112.49', 'Y112.772', 'E0.614193']
# ['G1', 'X112.541', 'Y112.726', 'E0.617391']
# ['G1', 'X112.84', 'Y112.406', 'E0.637784']
# ['G1', 'X113.049', 'Y112.099', 'E0.655077']
# ['G1', 'X113.21', 'Y111.77', 'E0.672133']
# ['G1', 'X113.336', 'Y111.355', 'E0.692328']
# ['G1', 'X113.394', 'Y110.925', 'E0.712532']
# ['G1', 'X113.4', 'Y109.201', 'E0.792809']
# ['G1', 'X113.361', 'Y108.776', 'E0.812682']
# ['G1', 'X113.334', 'Y108.623', 'E0.819916']
# ['G1', 'X113.183', 'Y108.171', 'E0.842107']
# ['G1', 'X112.977', 'Y107.785', 'E0.86248']
# ['G1', 'X112.757', 'Y107.491', 'E0.879578']
# ['G1', 'X112.391', 'Y107.149', 'E0.902903']
# ['G1', 'X112.023', 'Y106.909', 'E0.923361']
# ['G1', 'X111.682', 'Y106.758', 'E0.940727']
# ['G1', 'X111.264', 'Y106.645', 'E0.960889']
# ['G1', 'X110.8', 'Y106.6', 'E0.982596']
# ['G1', 'X109.3', 'Y106.6', 'E1.052443']
# ['G0', 'F7200', 'X109.2', 'Y106.6']
# ['G0', 'X108.431', 'Y107.14']
# ['G1', 'F1200', 'X108.046', 'Y107.33', 'E1.072434']
# ['G1', 'X107.748', 'Y107.55', 'E1.089682']
# ['G1', 'X107.491', 'Y107.819', 'E1.107006']
# ['G1', 'X107.282', 'Y108.126', 'E1.124299']
# ['G1', 'X107.152', 'Y108.401', 'E1.138463']
# ['G1', 'X107.048', 'Y108.757', 'E1.155733']
# ['G1', 'X107.003', 'Y109.124', 'E1.17295']
# ['G1', 'X107.0', 'Y110.8', 'E1.250992']
# ['G1', 'X107.037', 'Y111.186', 'E1.269048']
# ['G1', 'X107.059', 'Y111.304', 'E1.274637']
# ['G1', 'X107.14', 'Y111.569', 'E1.28754']
# ['G1', 'X107.33', 'Y111.954', 'E1.307532']
# ['G1', 'X107.55', 'Y112.252', 'E1.324779']
# ['G1', 'X107.819', 'Y112.509', 'E1.342103']
# ['G1', 'X108.126', 'Y112.718', 'E1.359396']
# ['G1', 'X108.401', 'Y112.848', 'E1.37356']
# ['G1', 'X108.757', 'Y112.952', 'E1.39083']
# ['G1', 'X109.124', 'Y112.997', 'E1.408047']
# ['G1', 'X110.8', 'Y113.0', 'E1.486089']
# ['G1', 'X111.186', 'Y112.963', 'E1.504145']
# ['G1', 'X111.304', 'Y112.941', 'E1.509734']
# ['G1', 'X111.569', 'Y112.86', 'E1.522637']
# ['G1', 'X111.954', 'Y112.67', 'E1.542629']
# ['G1', 'X112.252', 'Y112.45', 'E1.559876']
# ['G1', 'X112.509', 'Y112.181', 'E1.5772']
# ['G1', 'X112.718', 'Y111.874', 'E1.594493']
# ['G1', 'X112.848', 'Y111.599', 'E1.608657']
# ['G1', 'X112.952', 'Y111.243', 'E1.625927']
# ['G1', 'X112.997', 'Y110.876', 'E1.643144']
# ['G1', 'X113.0', 'Y109.2', 'E1.721186']
# ['G1', 'X112.963', 'Y108.814', 'E1.739242']
# ['G1', 'X112.941', 'Y108.696', 'E1.744831']
# ['G1', 'X112.805', 'Y108.301', 'E1.764284']
# ['G1', 'X112.627', 'Y107.978', 'E1.781457']
# ['G1', 'X112.44', 'Y107.736', 'E1.795697']
# ['G1', 'X112.169', 'Y107.481', 'E1.813024']
# ['G1', 'X111.861', 'Y107.275', 'E1.830278']
# ['G1', 'X111.52', 'Y107.124', 'E1.847644']
# ['G1', 'X111.164', 'Y107.032', 'E1.864765']
# ['G1', 'X110.8', 'Y107.0', 'E1.88178']
# ['G1', 'X109.2', 'Y107.0', 'E1.956283']
# ['G1', 'X108.814', 'Y107.037', 'E1.974339']
# ['G1', 'X108.696', 'Y107.059', 'E1.979928']
# ['G1', 'X108.497', 'Y107.12', 'E1.989605']
# ['G0', 'F7200', 'X108.431', 'Y107.14']
# ['G0', 'X107.818', 'Y108.049']
# ['G1', 'F1200', 'X107.644', 'Y108.297', 'E2.003712']
# ['G1', 'X107.514', 'Y108.572', 'E2.017876']
# ['G1', 'X107.433', 'Y108.864', 'E2.031986']
# ['G1', 'X107.401', 'Y109.166', 'E2.046127']
# ['G1', 'X107.4', 'Y110.8', 'E2.122213']
# ['G1', 'X107.435', 'Y111.146', 'E2.138407']
# ['G1', 'X107.451', 'Y111.223', 'E2.142069']
# ['G1', 'X107.522', 'Y111.449', 'E2.153099']
# ['G1', 'X107.655', 'Y111.721', 'E2.167198']
# ['G1', 'X107.831', 'Y111.967', 'E2.181282']
# ['G1', 'X108.049', 'Y112.182', 'E2.195539']
# ['G1', 'X108.297', 'Y112.356', 'E2.209646']
# ['G1', 'X108.572', 'Y112.486', 'E2.22381']
# ['G1', 'X108.864', 'Y112.567', 'E2.23792']
# ['G1', 'X109.166', 'Y112.599', 'E2.252061']
# ['G1', 'X110.8', 'Y112.6', 'E2.328148']
# ['G1', 'X111.146', 'Y112.565', 'E2.344341']
# ['G1', 'X111.223', 'Y112.549', 'E2.348003']
# ['G1', 'X111.449', 'Y112.478', 'E2.359033']
# ['G1', 'X111.721', 'Y112.345', 'E2.373132']
# ['G1', 'X111.967', 'Y112.169', 'E2.387217']
# ['G1', 'X112.182', 'Y111.951', 'E2.401474']
# ['G1', 'X112.356', 'Y111.703', 'E2.41558']
# ['G1', 'X112.486', 'Y111.428', 'E2.429744']
# ['G1', 'X112.567', 'Y111.136', 'E2.443854']
# ['G1', 'X112.599', 'Y110.834', 'E2.457996']
# ['G1', 'X112.6', 'Y109.2', 'E2.534082']
# ['G1', 'X112.565', 'Y108.854', 'E2.550275']
# ['G1', 'X112.549', 'Y108.777', 'E2.553937']
# ['G1', 'X112.452', 'Y108.489', 'E2.568088']
# ['G1', 'X112.31', 'Y108.223', 'E2.582128']
# ['G1', 'X112.123', 'Y107.981', 'E2.596369']
# ['G1', 'X111.899', 'Y107.776', 'E2.610508']
# ['G1', 'X111.644', 'Y107.611', 'E2.624651']
# ['G1', 'X111.364', 'Y107.492', 'E2.638818']
# ['G1', 'X111.07', 'Y107.421', 'E2.652901']
# ['G1', 'X110.8', 'Y107.4', 'E2.665511']
# ['G1', 'X109.2', 'Y107.4', 'E2.740014']
# ['G1', 'X108.854', 'Y107.435', 'E2.756207']
# ['G1', 'X108.777', 'Y107.451', 'E2.759869']
# ['G1', 'X108.551', 'Y107.522', 'E2.7709']
# ['G1', 'X108.279', 'Y107.655', 'E2.784998']
# ['G1', 'X108.033', 'Y107.831', 'E2.799083']
# ['G1', 'X107.872', 'Y107.994', 'E2.809776']
# ['G0', 'F7200', 'X107.818', 'Y108.049']
# ['G0', 'X107.8', 'Y109.2']
# ['G1', 'F1200', 'X107.8', 'Y110.8', 'E2.884279']
# ['G1', 'X107.833', 'Y111.103', 'E2.898471']
# ['G1', 'X107.904', 'Y111.329', 'E2.909502']
# ['G1', 'X108.011', 'Y111.539', 'E2.920476']
# ['G1', 'X108.152', 'Y111.729', 'E2.931493']
# ['G1', 'X108.324', 'Y111.892', 'E2.942528']
# ['G1', 'X108.52', 'Y112.024', 'E2.953531']
# ['G1', 'X108.736', 'Y112.121', 'E2.964557']
# ['G1', 'X108.964', 'Y112.18', 'E2.975523']
# ['G1', 'X109.2', 'Y112.2', 'E2.986551']
# ['G1', 'X110.8', 'Y112.2', 'E3.061054']
# ['G1', 'X111.103', 'Y112.167', 'E3.075246']
# ['G1', 'X111.329', 'Y112.096', 'E3.086277']
# ['G1', 'X111.539', 'Y111.989', 'E3.097252']
# ['G1', 'X111.729', 'Y111.848', 'E3.108269']
# ['G1', 'X111.892', 'Y111.676', 'E3.119303']
# ['G1', 'X112.024', 'Y111.48', 'E3.130306']
# ['G1', 'X112.121', 'Y111.264', 'E3.141332']
# ['G1', 'X112.18', 'Y111.036', 'E3.152298']
# ['G1', 'X112.2', 'Y110.8', 'E3.163327']
# ['G1', 'X112.2', 'Y109.2', 'E3.23783']
# ['G1', 'X112.167', 'Y108.897', 'E3.252022']
# ['G1', 'X112.096', 'Y108.671', 'E3.263053']
# ['G1', 'X111.989', 'Y108.461', 'E3.274027']
# ['G1', 'X111.848', 'Y108.271', 'E3.285045']
# ['G1', 'X111.676', 'Y108.108', 'E3.296078']
# ['G1', 'X111.48', 'Y107.976', 'E3.307082']
# ['G1', 'X111.264', 'Y107.879', 'E3.318107']
# ['G1', 'X111.036', 'Y107.82', 'E3.329074']
# ['G1', 'X110.8', 'Y107.8', 'E3.340102']
# ['G1', 'X109.2', 'Y107.8', 'E3.414605']
# ['G1', 'X108.897', 'Y107.833', 'E3.428797']
# ['G1', 'X108.671', 'Y107.904', 'E3.439828']
# ['G1', 'X108.461', 'Y108.011', 'E3.450803']
# ['G1', 'X108.271', 'Y108.152', 'E3.46182']
# ['G1', 'X108.108', 'Y108.324', 'E3.472854']
# ['G1', 'X107.976', 'Y108.52', 'E3.483857']
# ['G1', 'X107.879', 'Y108.736', 'E3.494883']
# ['G1', 'X107.82', 'Y108.964', 'E3.505849']
# ['G1', 'X107.81', 'Y109.082', 'E3.511364']
# ['G0', 'F7200', 'X107.8', 'Y109.2']
# ['G1', 'F1800', 'E-3.488636']
# ['G0', 'F7200', 'X108.4', 'Y109.41']
# ['G0', 'X109.2', 'Y109.689']
# ['G0', 'X109.5', 'Y109.794']
# ['G0', 'X109.951', 'Y109.951']
# ['G1', 'F1800', 'E3.511364']
# ['G0', 'F7200', 'X110.8', 'Y110.8']
# ['G1', 'F1200', 'X110.8', 'Y109.2', 'E3.585867']
# ['G1', 'X109.2', 'Y109.2', 'E3.66037']
# ['G1', 'X109.2', 'Y110.8', 'E3.734873']
# ['G1', 'X110.7', 'Y110.8', 'E3.804719']
# ['G0', 'F7200', 'X110.8', 'Y110.8']
# ['G0', 'X109.951', 'Y109.951']
# ['G0', 'X110.6', 'Y110.462']
# ['G1', 'F1200', 'X110.462', 'Y110.6', 'E3.813807']
# ['G0', 'F7200', 'X109.4', 'Y109.966']
# ['G1', 'F1200', 'X109.965', 'Y109.4', 'E3.851046']
# ['G0', 'F7200', 'X110.53', 'Y109.4']
# ['G1', 'F1200', 'X109.4', 'Y110.53', 'E3.925458']
# ['G0', 'F7200', 'X109.896', 'Y110.6']
# ['G1', 'F1200', 'X110.6', 'Y109.896', 'E3.971817']
# ['G1', 'F1800', 'E-3.028183']
# ['G0', 'F7200', 'X110.048', 'Y109.951']
# ['G92', 'E0']
# ['M106', 'S255']
# ['G1', 'Z0.56']
# ['G1', 'F1800', 'E7.0']
# ['G0', 'F7200', 'X109.2', 'Y110.8', 'Z0.56']
# ['G1', 'F2100', 'X110.8', 'Y110.8', 'E7.074503']
# ['G1', 'X110.8', 'Y109.2', 'E7.149006']
# ['G1', 'X109.2', 'Y109.2', 'E7.223509']
# ['G1', 'X109.2', 'Y110.7', 'E7.293356']
# ['G0', 'F7200', 'X109.2', 'Y110.8']
# ['G0', 'X110.048', 'Y109.951']
# ['G0', 'X109.4', 'Y110.462']
# ['G1', 'F2100', 'X109.537', 'Y110.6', 'E7.30241']
# ['G0', 'F7200', 'X110.6', 'Y109.966']
# ['G1', 'F2100', 'X110.034', 'Y109.4', 'E7.339683']
# ['G0', 'F7200', 'X109.469', 'Y109.4']
# ['G1', 'F2100', 'X110.6', 'Y110.531', 'E7.414161']
# ['G0', 'F7200', 'X110.103', 'Y110.6']
# ['G1', 'F2100', 'X109.4', 'Y109.896', 'E7.460487']
# ['G1', 'F1800', 'E0.460487']
# ['G0', 'F7200', 'X109.951', 'Y109.951']
# ['G92', 'E0']
# ['G1', 'Z0.84']
# ['G1', 'F1800', 'E7.0']
# ['G0', 'F7200', 'X110.8', 'Y110.8', 'Z0.84']
# ['G1', 'F2100', 'X110.8', 'Y109.2', 'E7.074503']
# ['G1', 'X109.2', 'Y109.2', 'E7.149006']
# ['G1', 'X109.2', 'Y110.8', 'E7.223509']
# ['G1', 'X110.7', 'Y110.8', 'E7.293356']
# ['G0', 'F7200', 'X110.8', 'Y110.8']
# ['G0', 'X109.951', 'Y109.951']
# ['G0', 'X110.462', 'Y110.6']
# ['G1', 'F2100', 'X110.6', 'Y110.462', 'E7.302443']
# ['G0', 'F7200', 'X109.965', 'Y109.4']
# ['G1', 'F2100', 'X109.4', 'Y109.966', 'E7.339682']
# ['G0', 'F7200', 'X109.4', 'Y110.53']
# ['G1', 'F2100', 'X110.53', 'Y109.4', 'E7.414094']
# ['G0', 'F7200', 'X110.6', 'Y109.896']
# ['G1', 'F2100', 'X109.896', 'Y110.6', 'E7.460454']
# ['G1', 'F1800', 'E0.460454']
# ['G0', 'F7200', 'X110.048', 'Y110.048']
# ['G92', 'E0']
# ['G1', 'Z1.12']
# ['G1', 'F1800', 'E7.0']
# ['G0', 'F7200', 'X109.2', 'Y109.2', 'Z1.12']
# ['G1', 'F2100', 'X109.2', 'Y110.8', 'E7.074503']
# ['G1', 'X110.8', 'Y110.8', 'E7.149006']
# ['G1', 'X110.8', 'Y109.2', 'E7.223509']
# ['G1', 'X109.3', 'Y109.2', 'E7.293356']
# ['G0', 'F7200', 'X109.2', 'Y109.2']
# ['G0', 'X110.048', 'Y110.048']
# ['G0', 'X109.4', 'Y109.774']
# ['G1', 'F3600', 'X109.774', 'Y109.4', 'E7.317984']
# ['G1', 'F7200', 'X109.774', 'Y109.4', 'E7.317984']
# ['G1', 'X109.4', 'Y109.774', 'E7.317984']
# ['G1', 'F1800', 'E0.317984']
# ['G0', 'F7200', 'X109.951', 'Y109.951']
# ['G92', 'E0']
# ['G1', 'Z1.4']
# ['G1', 'F1800', 'E7.0']
# ['G0', 'F7200', 'X110.8', 'Y110.8', 'Z1.4']
# ['G1', 'F2100', 'X110.8', 'Y109.2', 'E7.074503']
# ['G1', 'X109.2', 'Y109.2', 'E7.149006']
# ['G1', 'X109.2', 'Y110.8', 'E7.223509']
# ['G1', 'X110.7', 'Y110.8', 'E7.293356']
# ['G0', 'F7200', 'X110.8', 'Y110.8']
# ['G0', 'X109.951', 'Y109.951']
# ['G0', 'X110.6', 'Y110.462']
# ['G1', 'F2100', 'X110.462', 'Y110.6', 'E7.302443']
# ['G0', 'F7200', 'X109.4', 'Y109.966']
# ['G1', 'F2100', 'X109.965', 'Y109.4', 'E7.339682']
# ['G0', 'F7200', 'X110.53', 'Y109.4']
# ['G1', 'F2100', 'X109.4', 'Y110.53', 'E7.414094']
# ['G0', 'F7200', 'X109.896', 'Y110.6']
# ['G1', 'F2100', 'X110.6', 'Y109.896', 'E7.460454']
# ['G1', 'F1800', 'E0.460454']
# ['G0', 'F7200', 'X110.048', 'Y109.951']
# ['G92', 'E0']
# ['G1', 'Z1.68']
# ['G1', 'F1800', 'E7.0']
# ['G0', 'F7200', 'X109.2', 'Y110.8', 'Z1.68']
# ['G1', 'F2100', 'X110.8', 'Y110.8', 'E7.074503']
# ['G1', 'X110.8', 'Y109.2', 'E7.149006']
# ['G1', 'X109.2', 'Y109.2', 'E7.223509']
# ['G1', 'X109.2', 'Y110.7', 'E7.293356']
# ['G0', 'F7200', 'X109.2', 'Y110.8']
# ['G0', 'X110.048', 'Y109.951']
# ['G0', 'X109.4', 'Y110.462']
# ['G1', 'F2100', 'X109.537', 'Y110.6', 'E7.30241']
# ['G0', 'F7200', 'X110.6', 'Y109.966']
# ['G1', 'F2100', 'X110.034', 'Y109.4', 'E7.339683']
# ['G0', 'F7200', 'X109.469', 'Y109.4']
# ['G1', 'F2100', 'X110.6', 'Y110.531', 'E7.414161']
# ['G0', 'F7200', 'X110.103', 'Y110.6']
# ['G1', 'F2100', 'X109.4', 'Y109.896', 'E7.460487']
# ['G1', 'F1800', 'E0.460487']
# ['G0', 'F7200', 'X109.951', 'Y109.951']
# ['G92', 'E0']
# ['G1', 'Z1.96']
# ['G1', 'F1800', 'E7.0']
# ['G0', 'F7200', 'X110.8', 'Y110.8', 'Z1.96']
# ['G1', 'F2100', 'X110.8', 'Y109.2', 'E7.074503']
# ['G1', 'X109.2', 'Y109.2', 'E7.149006']
# ['G1', 'X109.2', 'Y110.8', 'E7.223509']
# ['G1', 'X110.7', 'Y110.8', 'E7.293356']
# ['G0', 'F7200', 'X110.8', 'Y110.8']
# ['G0', 'X109.951', 'Y109.951']
# ['G0', 'X110.6', 'Y110.462']
# ['G1', 'F2100', 'X110.462', 'Y110.6', 'E7.302443']
# ['G0', 'F7200', 'X109.896', 'Y110.6']
# ['G1', 'F2100', 'X110.6', 'Y109.896', 'E7.348802']
# ['G0', 'F7200', 'X110.53', 'Y109.4']
# ['G1', 'F2100', 'X109.4', 'Y110.53', 'E7.423215']
# ['G0', 'F7200', 'X109.4', 'Y109.966']
# ['G1', 'F2100', 'X109.965', 'Y109.4', 'E7.460454']
# ['G1', 'F1800', 'E0.460454']
# ['G0', 'F7200', 'X109.488', 'Y109.2']
# ['G0', 'X108.993', 'Y108.993']
# ['G92', 'E0']
# ['G1', 'Z2.24']
# ['G92', 'E0']
# ['G92', 'E0']
# ['M107']
# ['M104', 'S0']
# ['M140', 'S0']
# ['M107']
# ['G1', 'X0', 'Y0']
# ['G1', 'Y200']
# ['M84']
# ['M117', 'FTrue', 'ITrue', 'NTrue', 'STrue', 'HTrue', 'ETrue', 'DTrue']

# %%
X[65]
# Out:
# ['G1', 'X113.4', 'Y109.201', 'E0.792809']

# %%
from gcodeparser import GcodeParser

# open gcode file and store contents as variable
with open('cube.gcode', 'r') as f:
  gcode = f.read()

parsed_gcode = GcodeParser(gcode)
X=parsed_gcode.lines

# %%
for i in range (len (X)):
    X[i]=X[i].gcode_str

# %%
X[59]=X[59].split( )

# %%
# Out:
# 'X112.541'
